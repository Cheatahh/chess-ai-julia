# %%
HTML(read(open("style.html"), String))
# Out:
# HTML{String}("<link href='https://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>\r\n<link href='https://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>\r\n<link href='https://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>\r\n<link href='https://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>\r\n<link href='https://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>\r\n\r\n<style>\r\n\r\n@font-face {\r\n    font-family: \"Computer Modern\";\r\n    src: url('https://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');\r\n}\r\n\r\n.container { width: 100% }\r\n\r\n/* Formatting for header cells */\r\n.text_cell_render h1 {\r\n    font-family: 'Philosopher', sans-serif;\r\n    font-weight: 400
# ...

# %% [markdown]
# ***

# %% [markdown]
# # Literaturverzeichnis

# %% [markdown]
# Das Literaturverzeichnis sowie die Referenzen wurden mithilfe der Vorgaben der DHBW-Mannheim erstellt. Das Format (Autor / Jahr) wird verwendet, um die Referenzen im Text zu markieren.

# %% [markdown]
# Chess Programming WIKI Team. (05. 06 2023). CPW - David Forsyth. Von https://www.chessprogramming.org/David_Forsyth abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Forsyth-Edwards Notation. Von https://www.chessprogramming.org/Forsyth-Edwards_Notation abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - History Heuristic. Von https://www.chessprogramming.org/History_Heuristic abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Horizon Effect. Von https://www.chessprogramming.org/Horizon_Effect abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Killer Move. Von https://www.chessprogramming.org/Killer_Move abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Minimax. Von https://www.chessprogramming.org/Minimax abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Move Ordering. Von https://www.chessprogramming.org/Move_Ordering abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Portable Game Notation. Von https://www.chessprogramming.org/Portable_Game_Notation abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Quiescence search. Von https://www.chessprogramming.org/Quiescence_Search abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Steven Edwards. Von https://www.chessprogramming.org/Steven_Edwards abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Tomasz Michniewski. Von https://www.chessprogramming.org/Tomasz_Michniewski abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Zobrist Hashing. Von https://www.chessprogramming.org/Zobrist_Hashing abgerufen
#
# Chess Programming WIKI Team. (05. 06 2023). CPW - Zobrist Hashing - Theory. Von https://www.chessprogramming.org/Zobrist_Hashing#Theory abgerufen
#
# Chess.com. (05. 06 2023). Chess.com. Von https://www.chess.com/terms/threefold-repetition-chess abgerufen
#
# Great Learning Team. (05. 06 2023). GL - Alpha Beta Pruning in AI. Von https://www.mygreatlearning.com/blog/alpha-beta-pruning-in-ai/ abgerufen
#
# Johnson, S. G. (30. 05 2023). GitHub. Von https://github.com/stevengj abgerufen
#
# Julia. (05. 06 2023). Julia - Documentation. Von https://docs.julialang.org/en/v1/base/base/#Base.finalizer abgerufen
#
# Julia. (05. 06 2023). The Julia Programming Language . Von https://julialang.org/ abgerufen
#
# lichess.org. (05. 06 2023). lichess.org. Von https://lichess.org/editor abgerufen
#
# Michniewski, T. (05. 06 2023). CPW - Simplified Evaluation Function. Von https://www.chessprogramming.org/Simplified_Evaluation_Function abgerufen
#
# Romstad, T. (05. 06 2023). Chess.jl. Von https://romstad.github.io/Chess.jl/dev/ abgerufen
#
# Romstad, T. (05. 06 2023). GitHub. Von https://github.com/romstad abgerufen
#
# stevengj, e. K. (30. 05 2023). GitHub - NBInclude.jl. Von https://github.com/JuliaInterop/NBInclude.jl abgerufen
#
# WikiBooks. (05. 06 2023). Wikibooks - Sicilian Defence. Von https://en.wikibooks.org/wiki/Chess_Opening_Theory/1._e4/1...c5 abgerufen
#
# Wikipedia. (05. 06 2023). Race condition. Von https://en.wikipedia.org/wiki/Race_condition abgerufen

# %% [markdown]
# ***
